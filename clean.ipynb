# %%
import sys
import cv2
import glob
import os

# %%
dir_path = "./data/youtube/processed/"

for filename in glob.iglob('./data/youtube/processed/*.jpg'):
    print(filename)
    imgNum = filename.split('_')[1]
    imgNum = imgNum.split('.')[0]
    print(imgNum)
    if(int(imgNum)>9):
        os.remove(filename)
# Out:
# ./data/youtube/processed/vid30_6.jpg
# 6
# ./data/youtube/processed/vid1818_6.jpg
# 6
# ./data/youtube/processed/vid1791_0.jpg
# 0
# ./data/youtube/processed/vid536_9.jpg
# 9
# ./data/youtube/processed/vid479_1.jpg
# 1
# ./data/youtube/processed/vid544_1.jpg
# 1
# ./data/youtube/processed/vid1108_0.jpg
# 0
# ./data/youtube/processed/vid727_3.jpg
# 3
# ./data/youtube/processed/vid704_7.jpg
# 7
# ./data/youtube/processed/vid985_7.jpg
# 7
# ./data/youtube/processed/vid993_2.jpg
# 2
# ./data/youtube/processed/vid706_2.jpg
# 2
# ./data/youtube/processed/vid1218_0.jpg
# 0
# ./data/youtube/processed/vid1897_6.jpg
# 6
# ./data/youtube/processed/vid844_2.jpg
# 2
# ./data/youtube/processed/vid150_0.jpg
# 0
# ./data/youtube/processed/vid1931_5.jpg
# 5
# ./data/youtube/processed/vid852_4.jpg
# 4
# ./data/youtube/processed/vid1010_7.jpg
# 7
# ./data/youtube/processed/vid1139_5.jpg
# 5
# ./data/youtube/processed/vid335_2.jpg
# 2
# ./data/youtube/processed/vid530_1.jpg
# 1
# ...
